# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaMeza/Metodos-numericos-2/blob/main/Grafica_lagrange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as up
import matplotlib.pyplot as plt

# %%
plt.scatter(1.0,0.7651977)
plt.scatter(1.3,0.6200860)
plt.scatter(1.6,0.4554022)
plt.scatter(1.9,0.2818186)
plt.scatter(2.2,0.1103623)
